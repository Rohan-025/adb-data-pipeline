# %%
print('This is the first notebook')

# %%
print('made some changes for the test')

# %%
print('adding this for reference')

# %%
print('checking')

# %%
print("Test commit from dev branch")

# %%
print('testing only for dev')
